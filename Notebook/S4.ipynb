# %% [markdown]
# # S4 流程
#
# 本 Notebook 演示训练数据读取、模型构建、训练与保存。

# %%
import sys
sys.path.append(r"d:\Desktop\Spike sort")



from Main.S4 import load_training_data, build_simple_mlp, train_model, save_model,Resnet

# %%
train_dir = "../Data/Train data/Waveform data/Binary class/Train_data.mat"
data = load_training_data(train_dir)
data.X.shape
data.y.shape
# Out:
# (1104642,)

# %%
#MLP
#最简单的模型
model = build_simple_mlp(input_dim=data.X.shape[1], num_classes=int(data.y.max()) + 1)
model
# Out:
# Sequential(
#   (0): Linear(in_features=10, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=128, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
#Resnet
#复杂度更高，但消耗的时间与gpu也更多
#model = Resnet(num_classes=int(data.y.max()) + 1)
#model

# %%
model = train_model(data, model=model, batch_size=128, epochs=10, lr=1e-3, plot_history=True, device="cpu")

# %%
save_model(model, "../Model/simple_mlp.pt")
